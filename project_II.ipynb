# %%
import ds
import time
from datetime import date
import datetime
from csv import DictWriter

a_dict={}
queue=[]
front=None
def place_order():
    
    c,v,s,b,t=0,0,0,0,0
    global k1,k2,k3,k4,k5
    list1=[]
    list2=[]
    list3=[]
    list4=[]
    list5=[]
    c1,v1,s1,b1,t1=0,0,0,0,0
    while True:
        a_dict={}
        print("\nWhat would you like to have?? ")
        print("\n______________MENU CARD____________________")
        print("1.Chocolate ice-creame......Rs 100/pc")
        print("2.Vanilla Ice-cream.........Rs 70/pc")
        print("3.Strawberry Ice-cream......Rs 80/pc")
        print("4.ButterScotch Ice-cream....Rs 110/pc")
        print("5.Tutti fruiti Ice-Creame...Rs 120/pc")
        print("_____________________________________________")
        ch1=int(input("\n enter your choice(1..5):"))
        print("---------------------------------------------")
        if ch1==1:
            c1=1
            k1=int(input("\nHow many chocolate icecreams you want?"))
            c=c+k1
            c1=k1
            print("\nOrder list updated, chocolate ice-cream added to cart")
            
           
        
        elif ch1==2:
            k2=int(input("\nHow many Vanilla icecreams you want?"))
            v+=k2
            v1=k2
            print("\nOrder list updated,vnilla icecreame added to cart")
        elif ch1==3:
            s1=1
            k3=int(input("\nHow many Stwaberry  icecreams you want?"))
            s+=k3
            s1=k3
            print("\nOrder list updated,stawberry icecreame added to cart")
        elif ch1==4:
            b1=1
            k4=int(input("\nHow many butterscotch icecreams you want?"))
            b+=k4
            b1=k4
            print("\nOrder list updated,butterscotch icecream added to cart")
        elif ch1==5:
            t1=1
            k5=int(input("\nHow many tutti fruiti  icecreams you want?"))
            t+=k5
            t1=k5
            print("\nOrder list updated,tutti friti icecream added to cart")
        else:
            print("please enter valid option!")
            continue
        
        ch2=input("\nwant to add more items to card? press y to add more items or any other key to exit: ")
        if  ch2=="y" or ch2=="Y":
            
            continue
        else:
            print("\n****************Thanks for placing order****************** ")
            print("Your order is:")
             
            if c1>0:
                print("chocolate icecream-",c)
                total1=c*100
                list1.append(c)
                list1.append(total1)
                a_dict["chocolate"]=list1
                
                
            if v1>0: 
                print("Vanilla icecream-",v)
                total2=v*70
                list2.append(v)
                list2.append(total2)
                a_dict["vanilla"]=list2
                
            if s1>0:
                print("Stwaberry icecream-",s)
                total3=s*80
                list3.append(s)
                list3.append(total3)
                a_dict["stwaberry"]=list3
                
            if b1>0:
                print("Butterscotch icecream-",b) 
                total4=b*110
                list4.append(b)
                list4.append(total4)
                a_dict["butterscotch"]=list4
                
            if t1>0:
                print("truti friti icecream-",t) 
                total5=t*120
                list5.append(t)
                list5.append(total5)
                a_dict["Truti fruti"]=list5
            print("*****************************************************************")   
            break 
    item=a_dict
    ds.Enqueue(queue,item)

# %%
def pop1():
    x=datetime.datetime.now()
    day=x.strftime("%A")
    date1=date.today()
    p=ds.Dequeue(queue)
    items=p.keys()
    items=list(items)
    val=p.values()
    val=list(val)
    l=len(val)
    i1=p.items()
    i1=list(i1)
    if l==1:
        total=val[0][1]
        i=items[0]
        q=val[0][0]
        t1=val[0][1]
        
        o=items[0]
        q=val[0][0]
        final_item={o:q}
        
    elif l==2:
        total=val[0][1]+val[1][1]
        i=items[0]
        q=val[0][0]
        t1=val[0][1]
        
        i2=items[1]
        q2=val[1][0]
        t2=val[1][1]
        
        o=items[0]
        q=val[0][0]
        o1=items[1]
        q1=val[1][0]
        final_item={o:q,o1:q1}
    
    elif l==3:
        total=val[0][1]+val[1][1]+val[2][1]
        
        i=items[0]
        q=val[0][0]
        t1=val[0][1]
        
        i2=items[1]
        q2=val[1][0]
        t2=val[1][1]
        
        i3=items[2]
        q3=val[2][0]
        q4=val[2][1]
        
        o=items[0]
        q=val[0][0]
        o1=items[1]
        q1=val[1][0]
        o2=items[2]
        q2=val[2][0]
        final_item={o:q,o1:q1,o2:q2}
    
    elif l==4:
        total=val[0][1]+val[1][1]+val[2][1]+val[3][1]
        
        i=items[0]
        q=val[0][0]
        t1=val[0][1]
        
        i2=items[1]
        q2=val[1][0]
        t2=val[1][1]
        
        i3=items[2]
        q3=val[2][0]
        t3=val[2][1]
        
        i4=items[3]
        q4=val[3][0]
        t4=val[3][1]
        
        o=items[0]
        q=val[0][0]
        o1=items[1]
        q1=val[1][0]
        o2=items[2]
        q2=val[2][0]
        o3=items[3]
        q3=val[3][0]
        final_item={o:q,o1:q1,o2:q2,o3:q3}
    
    
        
    elif l==5:
        total=val[0][1]+val[1][1]+val[2][1]+val[3][1]+val[4][1]
        
        i=items[0]
        q=val[0][0]
        t1=val[0][1]
        
        i2=items[1]
        q2=val[1][0]
        t2=val[1][1]
        
        i3=items[2]
        q3=val[2][0]
        t3=val[2][1]
        
        i4=items[3]
        q4=val[3][0]
        t4=val[3][1]
        
        i5=items[4]
        q5=val[4][0]
        t5=val[4][1]    
        
        o=items[0]
        q=val[0][0]
        o1=items[1]
        q1=val[1][0]
        o2=items[2]
        q2=val[2][0]
        o3=items[3]
        q3=val[3][0]
        o4=items[4]
        q4=val[4][0]
        final_item={o:q,o1:q1,o2:q2,o3:q3,o4:q4}
    
    
        
    else:
        pass

    if day=="Saturday" or "Sunday":
        discount_amount=total*5/100
        final_amount=total-discount_amount
    
    elif total>650:
        discount_amount=total*5/100
        final_amount=total-discount_amount
    
    elif (day=="Saturday" or "Sunday") and (total>650):
        discount_amount=total*10/100
        final_amount=total-discount_amount
    else:
        discount_amount=0
        final_amount=total
    print("*************Order to be deliver****************************")
    print(day)
    print(date1)
    if l==1:
        print(i,":",q,"=",t1)
    elif l==2:
        print(i,":",q,"=",t1,"\n",i2,":",q2,"=",t2)
    elif l==3:
        print(i,":",q,"=",t1,"\n",i2,":",q2,"=",t2,"\n",i3,":",q3,"=",t3)
    elif l==4:
        print(i,":",q,"=",t1,"\n",i2,":",q2,"=",t2,"\n",i3,":",q3,"=",t3,"\n",i4,":",q4,"=",t4)
    elif l==5:
        print(i,":",q,"=",t1,"\n",i2,":",q2,"=",t2,"\n",i3,":",q3,"=",t3,"\n",i4,":",q4,"=",t4,"\n",i5,":",q5,"=",t5)
    else:pass
    print("total Amount:",total)
    print("Discount amount:",discount_amount)
    print("final amount to be paid:",final_amount)
    print("*************************************************************")
    str3=str(final_item)
    str4=str(total)
    str5=str(discount_amount)
    str6=str(final_amount)
    field_names=["Day","Date","Item","total","discount","discount_total"]
    
    dict={"Day":day,"Date":date1,"Item":final_item,"total":str4,"discount":str5,"discount_total":str6}
    with open("sales_record.csv","a") as f_object:
        dict_writer=DictWriter(f_object,fieldnames=field_names)
        dict_writer.writerow(dict)
        f_object.close()

# %%
while True:
    print("\nWelcome to the world's best Ice cream corner:")
   
    print("1.place order")
    print("2.order to be delivered")
    print("3.waiting queue")
    print("4.exit")
   
    ch=int(input("enter your choice(1...4):"))
   
    if ch==1:
        place_order()

   
    elif ch==3:
        if ds.isEmpty(queue):
            print("No order in waiting list\n")
        else:
            print("***************your order is ready*****************")
            ds.Display(queue)
            print("******************************************************")
    elif ch==2:
        if ds.isEmpty(queue):
            print("No order in waiting list\n")
        else:
            pop1()
    elif ch==4:
        print("Thanks for visiting our parlour!!see you again!")
        break
    else:
        print("invalid choice!!")
# Out:
# Welcome to the world's best Ice cream corner:
# 1.place order
# 2.order to be delivered
# 3.waiting queue
# 4.exit
# enter your choice(1...4):2
# No order in waiting list
#
#
# Welcome to the world's best Ice cream corner:
# 1.place order
# 2.order to be delivered
# 3.waiting queue
# 4.exit
# enter your choice(1...4):3
# No order in waiting list
#
#
# Welcome to the world's best Ice cream corner:
# 1.place order
# 2.order to be delivered
# 3.waiting queue
# 4.exit
# enter your choice(1...4):1
#
# What would you like to have??
#
# ______________MENU CARD____________________
# 1.Chocolate ice-creame......Rs 100/pc
# 2.Vanilla Ice-cream.........Rs 70/pc
# 3.Strawberry Ice-cream......Rs 80/pc
# 4.ButterScotch Ice-cream....Rs 110/pc
# 5.Tutti fruiti Ice-Creame...Rs 120/pc
# _____________________________________________
#
#  enter your choice(1..5):1
# ---------------------------------------------
#
# How many chocolate icecreams you want?2
#
# ...
